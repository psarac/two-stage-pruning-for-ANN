# %% [markdown]
# # Dependencies

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import random_split, DataLoader
import numpy as np

# %% [markdown]
# # Set Random Seed

# %%
import numpy as np
import random

# Set seed
def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False  # Ensures deterministic behavior

set_seed(42)

# %% [markdown]
# # Find Device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Hyperparameters

# %%
batch_size = 128 # batch size
num_epochs = 30 # number of epochs
learning_rate = 0.001 # learning rate

# %% [markdown]
# # Prepare Dataset: CIFAR-10

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                              download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                             download=True, transform=transform)

val_size = 10000 # Corresponds to 20% of training set
train_size = len(train_dataset) - val_size
train_data, val_data = random_split(train_dataset, [train_size, val_size])

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# 100%|██████████| 170M/170M [00:02<00:00, 73.4MB/s]

# %% [markdown]
# # Model: ResNet18

# %%
class ResNet18_CIFAR10(nn.Module):
    def __init__(self):
        super(ResNet18_CIFAR10, self).__init__()
        self.model = torchvision.models.resnet18(pretrained=False, num_classes=10)
        # Updating so that compatible with image sizes
        self.model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.model.maxpool = nn.Identity()

    def forward(self, x):
        return self.model(x)

model = ResNet18_CIFAR10().to(device)

# %% [markdown]
# # Loss Function and Optimizer

# %%
criterion = nn.CrossEntropyLoss() # Cross Entropy
optimizer = optim.Adam(model.parameters(), lr=learning_rate) # ADAM Optimizer

# %% [markdown]
# # Training with Validation for Baseline

# %%
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    train_losses.append(running_loss / total)
    train_accuracies.append(correct / total)

    # Validation
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            val_total += targets.size(0)
            val_correct += predicted.eq(targets).sum().item()

    val_losses.append(val_loss / val_total)
    val_accuracies.append(val_correct / val_total)

    print(f"Epoch [{epoch+1}/{num_epochs}] Train Acc: {train_accuracies[-1]*100:.2f}%  Val Acc: {val_accuracies[-1]*100:.2f}%")
# Out:
# Epoch [1/30] Train Acc: 53.59%  Val Acc: 54.63%
# Epoch [2/30] Train Acc: 71.68%  Val Acc: 73.60%
# Epoch [3/30] Train Acc: 79.55%  Val Acc: 75.80%
# Epoch [4/30] Train Acc: 84.51%  Val Acc: 76.09%
# Epoch [5/30] Train Acc: 88.37%  Val Acc: 76.86%
# Epoch [6/30] Train Acc: 91.37%  Val Acc: 80.35%
# Epoch [7/30] Train Acc: 94.33%  Val Acc: 77.35%
# Epoch [8/30] Train Acc: 95.60%  Val Acc: 79.55%
# Epoch [9/30] Train Acc: 96.57%  Val Acc: 81.58%
# Epoch [10/30] Train Acc: 97.50%  Val Acc: 80.91%
# Epoch [11/30] Train Acc: 97.69%  Val Acc: 81.14%
# Epoch [12/30] Train Acc: 97.84%  Val Acc: 81.17%
# Epoch [13/30] Train Acc: 98.43%  Val Acc: 79.80%
# Epoch [14/30] Train Acc: 98.26%  Val Acc: 82.44%
# Epoch [15/30] Train Acc: 98.30%  Val Acc: 81.93%
# Epoch [16/30] Train Acc: 98.32%  Val Acc: 81.78%
# Epoch [17/30] Train Acc: 98.56%  Val Acc: 81.97%
# Epoch [18/30] Train Acc: 98.77%  Val Acc: 81.56%
# Epoch [19/30] Train Acc: 98.86%  Val Acc: 81.34%
# Epoch [20/30] Train Acc: 98.86%  Val Acc: 81.93%
# Epoch [21/30] Train Acc: 98.95%  Val Acc: 82.01%
# Epoch [22/30] Train Acc: 98.65%  Val Acc: 81.25%
# Epoch [23/30] Train Acc: 98.83%  Val Acc: 83.06%
# Epoch [24/30] Train Acc: 99.21%  Val Acc: 81.99%
# Epoch [25/30] Train Acc: 99.41%  Val Acc: 83.52%
# Epoch [26/30] Train Acc: 98.41%  Val Acc: 81.24%
# Epoch [27/30] Train Acc: 99.17%  Val Acc: 83.79%
# Epoch [28/30] Train Acc: 99.62%  Val Acc: 83.88%
# Epoch [29/30] Train Acc: 99.05%  Val Acc: 78.64%
# Epoch [30/30] Train Acc: 98.91%  Val Acc: 83.12%

# %% [markdown]
# # Train Accuracy

# %%
model.eval()
test_correct = 0
test_total = 0
with torch.no_grad():
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        test_total += targets.size(0)
        test_correct += predicted.eq(targets).sum().item()

print(f"\nTrain Accuracy: {100 * test_correct / test_total:.2f}%")
# Out:
# Train Accuracy: 99.28%

# %% [markdown]
# # Test Accuracy

# %%
model.eval()
test_correct = 0
test_total = 0
with torch.no_grad():
    for inputs, targets in test_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        test_total += targets.size(0)
        test_correct += predicted.eq(targets).sum().item()

print(f"\nTest Accuracy: {100 * test_correct / test_total:.2f}%")
# Out:
# Test Accuracy: 82.88%

# %% [markdown]
# # Plots

# %%
epochs = range(1, num_epochs + 1)
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, val_losses, label='Val Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, [100*acc for acc in train_accuracies], label='Train Acc', marker='o')
plt.plot(epochs, [100*acc for acc in val_accuracies], label='Val Acc', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.title('Accuracy Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # With Pruning

# %%
import torch.nn.utils.prune as prune

# %% [markdown]
# ## Hyperparameters

# %%
batch_size = 128
num_epochs = 30
learning_rate = 0.001

# Extra hyperparameters needed for pruning
prune_interval = 1
percentile = 90

# %% [markdown]
# ## Pruning method

# %%
def structured_filter_prune(model, percentile):
    total_filters = 0
    pruned_filters = 0
    for name, module in model.named_modules():
        if isinstance(module, nn.Conv2d):
            weight = module.weight.data
            grad = module.weight.grad

            if grad is None:
                continue

            # Compute mean weight and grad for each filter (output channel)
            mean_weight = weight.view(weight.size(0), -1).abs().mean(dim=1)
            mean_grad = grad.view(grad.size(0), -1).abs().mean(dim=1)

            weight_thresh = torch.quantile(mean_weight, percentile / 100)
            grad_thresh = torch.quantile(mean_grad, percentile / 100)

            # Determine filters to prune
            prune_mask = (mean_weight < weight_thresh) & (mean_grad < grad_thresh)

            for idx, should_prune in enumerate(prune_mask):
                if should_prune:
                    weight[idx] = 0  # Soft pruning by zeroing out filter
                    pruned_filters += 1

            total_filters += weight.size(0)

    return pruned_filters, total_filters

# %% [markdown]
# ## Sparsity Function

# %%
def calculate_weight_sparsity(model):
    total_weights = 0
    zero_weights = 0
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            weight = module.weight.data
            total_weights += weight.numel()
            zero_weights += (weight == 0).sum().item()
    return 100 * zero_weights / total_weights

# %% [markdown]
# ## Training with validation and pruning

# %%
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    train_losses.append(running_loss / total)
    train_accuracies.append(correct / total)

    # Validation
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            val_total += targets.size(0)
            val_correct += predicted.eq(targets).sum().item()

    val_losses.append(val_loss / val_total)
    val_accuracies.append(val_correct / val_total)

    print(f"Epoch [{epoch+1}/{num_epochs}] Train Acc: {train_accuracies[-1]*100:.2f}%  Val Acc: {val_accuracies[-1]*100:.2f}%")

    # Apply pruning
    if (epoch + 1) % prune_interval == 0:
        pruned, total = structured_filter_prune(model, percentile)
        print(f"Pruned {pruned}/{total} filters ({100 * pruned / total:.2f}%) at epoch {epoch+1}")
# Out:
# Epoch [1/30] Train Acc: 54.00%  Val Acc: 64.60%
# Pruned 3891/4800 filters (81.06%) at epoch 1
# Epoch [2/30] Train Acc: 37.57%  Val Acc: 47.57%
# Pruned 3845/4800 filters (80.10%) at epoch 2
# Epoch [3/30] Train Acc: 37.30%  Val Acc: 43.64%
# Pruned 3850/4800 filters (80.21%) at epoch 3
# Epoch [4/30] Train Acc: 40.45%  Val Acc: 47.23%
# Pruned 3839/4800 filters (79.98%) at epoch 4
# Epoch [5/30] Train Acc: 40.13%  Val Acc: 45.72%
# Pruned 3838/4800 filters (79.96%) at epoch 5
# Epoch [6/30] Train Acc: 41.42%  Val Acc: 48.48%
# Pruned 3837/4800 filters (79.94%) at epoch 6
# Epoch [7/30] Train Acc: 42.77%  Val Acc: 50.28%
# Pruned 3838/4800 filters (79.96%) at epoch 7
# Epoch [8/30] Train Acc: 44.26%  Val Acc: 51.73%
# Pruned 3829/4800 filters (79.77%) at epoch 8
# Epoch [9/30] Train Acc: 46.47%  Val Acc: 51.48%
# Pruned 3835/4800 filters (79.90%) at epoch 9
# Epoch [10/30] Train Acc: 45.95%  Val Acc: 53.38%
# Pruned 3848/4800 filters (80.17%) at epoch 10
# Epoch [11/30] Train Acc: 47.30%  Val Acc: 51.96%
# Pruned 3839/4800 filters (79.98%) at epoch 11
# Epoch [12/30] Train Acc: 49.81%  Val Acc: 51.85%
# Pruned 3837/4800 filters (79.94%) at epoch 12
# Epoch [13/30] Train Acc: 51.30%  Val Acc: 55.58%
# Pruned 3843/4800 filters (80.06%) at epoch 13
# Epoch [14/30] Train Acc: 49.84%  Val Acc: 54.15%
# Pruned 3853/4800 filters (80.27%) at epoch 14
# Epoch [15/30] Train Acc: 52.81%  Val Acc: 60.09%
# Pruned 3842/4800 filters (80.04%) at epoch 15
# Epoch [16/30] Train Acc: 54.69%  Val Acc: 60.52%
# Pruned 3849/4800 filters (80.19%) at epoch 16
# Epoch [17/30] Train Acc: 56.19%  Val Acc: 59.04%
# Pruned 3871/4800 filters (80.65%) at epoch 17
# Epoch [18/30] Train Acc: 55.40%  Val Acc: 59.70%
# Pruned 3891/4800 filters (81.06%) at epoch 18
# Epoch [19/30] Train Acc: 58.61%  Val Acc: 61.05%
# Pruned 3872/4800 filters (80.67%) at epoch 19
# Epoch [20/30] Train Acc: 58.22%  Val Acc: 64.46%
# Pruned 3865/4800 filters (80.52%) at epoch 20
# Epoch [21/30] Train Acc: 60.28%  Val Acc: 65.51%
# Pruned 3868/4800 filters (80.58%) at epoch 21
# Epoch [22/30] Train Acc: 62.27%  Val Acc: 65.79%
# Pruned 3855/4800 filters (80.31%) at epoch 22
# Epoch [23/30] Train Acc: 61.46%  Val Acc: 63.91%
# Pruned 3876/4800 filters (80.75%) at epoch 23
# Epoch [24/30] Train Acc: 63.50%  Val Acc: 64.82%
# Pruned 3875/4800 filters (80.73%) at epoch 24
# Epoch [25/30] Train Acc: 64.21%  Val Acc: 68.26%
# Pruned 3876/4800 filters (80.75%) at epoch 25
# Epoch [26/30] Train Acc: 65.29%  Val Acc: 67.90%
# Pruned 3885/4800 filters (80.94%) at epoch 26
# Epoch [27/30] Train Acc: 66.33%  Val Acc: 67.02%
# Pruned 3895/4800 filters (81.15%) at epoch 27
# Epoch [28/30] Train Acc: 67.43%  Val Acc: 69.76%
# Pruned 3880/4800 filters (80.83%) at epoch 28
# Epoch [29/30] Train Acc: 68.52%  Val Acc: 69.90%
# Pruned 3879/4800 filters (80.81%) at epoch 29
# Epoch [30/30] Train Acc: 69.70%  Val Acc: 68.83%
# Pruned 3893/4800 filters (81.10%) at epoch 30

# %%
sparsity = calculate_weight_sparsity(model)
print(f"Final convolutional weight sparsity: {sparsity:.2f}%")
# Out:
# Final convolutional weight sparsity: 82.10%

# %% [markdown]
# ## Train Accuracy

# %%
model.eval()
test_correct = 0
test_total = 0
with torch.no_grad():
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        test_total += targets.size(0)
        test_correct += predicted.eq(targets).sum().item()

print(f"\nTrain Accuracy: {100 * test_correct / test_total:.2f}%")
# Out:
# Train Accuracy: 10.01%

# %% [markdown]
# ## Test Accuracy

# %%
model.eval()
test_correct = 0
test_total = 0
with torch.no_grad():
    for inputs, targets in test_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        _, predicted = outputs.max(1)
        test_total += targets.size(0)
        test_correct += predicted.eq(targets).sum().item()

print(f"\nTest Accuracy: {100 * test_correct / test_total:.2f}%")
# Out:
# Test Accuracy: 10.04%

# %% [markdown]
# ## Plots

# %%
epochs = range(1, num_epochs + 1)
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, val_losses, label='Val Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, [100*acc for acc in train_accuracies], label='Train Acc', marker='o')
plt.plot(epochs, [100*acc for acc in val_accuracies], label='Val Acc', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
plt.title('Accuracy Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
